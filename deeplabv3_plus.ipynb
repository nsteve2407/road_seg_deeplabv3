# %% [markdown]
# # Multiclass semantic segmentation using DeepLabV3+
#
# **Author:** [Soumik Rakshit](http://github.com/soumik12345)<br>
# **Date created:** 2021/08/31<br>
# **Last modified:** 2021/09/1<br>
# **Description:** Implement DeepLabV3+ architecture for Multi-class Semantic Segmentation.

# %% [markdown]
# ## Introduction
#
# Semantic segmentation, with the goal to assign semantic labels to every pixel in an image,
# is an essential computer vision task. In this example, we implement
# the **DeepLabV3+** model for multi-class semantic segmentation, a fully-convolutional
# architecture that performs well on semantic segmentation benchmarks.
#
# ### References:
#
# - [Encoder-Decoder with Atrous Separable Convolution for Semantic Image Segmentation](https://arxiv.org/pdf/1802.02611.pdf)
# - [Rethinking Atrous Convolution for Semantic Image Segmentation](https://arxiv.org/abs/1706.05587)
# - [DeepLab: Semantic Image Segmentation with Deep Convolutional Nets, Atrous Convolution, and Fully Connected CRFs](https://arxiv.org/abs/1606.00915)

# %% [markdown]
# ## Downloading the data
#
# We will use the [Crowd Instance-level Human Parsing Dataset](https://arxiv.org/abs/1811.12596)
# for training our model. The Crowd Instance-level Human Parsing (CIHP) dataset has 38,280 diverse human images.
# Each image in CIHP is labeled with pixel-wise annotations for 20 categories, as well as instance-level identification.
# This dataset can be used for the "human part segmentation" task.

# %%
import os
import cv2
import numpy as np
from glob import glob
from scipy.io import loadmat
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f662fcda-5982-44a0-b4f4-e71cd08132d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f662fcda-5982-44a0-b4f4-e71cd08132d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: images/
#   inflating: images/r16219069037040.jpeg
#   inflating: images/r16219168976000.jpeg
#   inflating: images/r16219268910540.jpeg
#   inflating: images/r16219368858940.jpeg
#   inflating: images/r16219468840110.jpeg
#   inflating: images/r16219568818820.jpeg
#   inflating: images/r16219668825490.jpeg
#   inflating: images/r16219768829010.jpeg
#   inflating: images/r16219868842610.jpeg
#   inflating: images/r16219968901180.jpeg
#   inflating: images/r16220068924700.jpeg
#   inflating: images/r16220168928920.jpeg
#   inflating: images/r16220268891070.jpeg
#   inflating: images/r16220368836770.jpeg
#   inflating: images/r16220468777280.jpeg
#   inflating: images/r16271868052300.jpeg
#   inflating: images/r16271968044680.jpeg
#   inflating: images/r16272068063050.jpeg
#   inflating: images/r16272168055620.jpeg
#   inflating: images/r16272268048110.jpeg
#   inflating: images/r16272368039380.jpeg
#   inflating: images/r16272468030270.jpeg
#   inflating: images/r16272568020360.jpeg
#   inflating: images/r16272668022140.jpeg
#   inflating: images/r16272768027480.jpeg
#   inflating: images/r16272868048060.jpeg
#   inflating: images/r16272968091130.jpeg
#   inflating: images/r16273068119390.jpeg
#   inflating: images/r16273168175070.jpeg
#   inflating: images/r16273268230490.jpeg
#   inflating: images/r16273368270120.jpeg
#   inflating: images/r16273468280610.jpeg
#   inflating: images/r16273568252280.jpeg
#   inflating: images/r16273668206670.jpeg
#   inflating: images/r16273768151640.jpeg
#   inflating: images/r16273868108470.jpeg
#   inflating: images/r16273968084080.jpeg
#   inflating: images/r16274068062510.jpeg
#   inflating: images/r16274168050640.jpeg
#   inflating: images/r16274268034350.jpeg
#   inflating: images/r16274368012530.jpeg
#   inflating: images/r16274467969630.jpeg
#   inflating: images/r16274567955650.jpeg
#   inflating: images/r16274667949910.jpeg
#   inflating: images/r16274767959340.jpeg
#   inflating: images/r16274867951230.jpeg
#   inflating: images/r16274967955390.jpeg
#   inflating: images/r16275067955140.jpeg
#   inflating: images/r16275167966110.jpeg
#   inflating: images/r16275267994810.jpeg
#   inflating: images/r16275368041110.jpeg
#   inflating: images/r16275468074400.jpeg
#   inflating: images/r16275568084270.jpeg
#   inflating: images/r17136458354500.jpeg
#   inflating: images/r17136558333950.jpeg
#   inflating: images/r17136658280820.jpeg
#   inflating: images/r17136758250230.jpeg
#   inflating: images/r17136858258640.jpeg
#   inflating: images/r17136958261380.jpeg
#   inflating: images/r17137058248100.jpeg
#   inflating: images/r17137158240330.jpeg
#   inflating: images/r17137258244460.jpeg
#   inflating: images/r17137358235650.jpeg
#   inflating: images/r17154358086040.jpeg
#   inflating: images/r17253450946200.jpeg
#   inflating: images/r17253550885830.jpeg
#   inflating: images/r17253650837230.jpeg
#   inflating: images/r17253750828620.jpeg
#   inflating: images/r17317746189830.jpeg
#   inflating: images/r17317846168890.jpeg
#   inflating: images/r17317946149190.jpeg
#   inflating: images/r17318046095120.jpeg
#   inflating: images/r17318146067720.jpeg
#   inflating: images/r17318246050470.jpeg
#   inflating: images/r17318346038420.jpeg
#   inflating: images/r17318446021830.jpeg
#   inflating: images/r17318546035810.jpeg
#   inflating: images/r17318646058340.jpeg
#   inflating: images/r17318746085700.jpeg
#   inflating: images/r17318846127960.jpeg
#   inflating: images/r17318946146980.jpeg
#   inflating: images/r17442743457510.jpeg
#   inflating: images/r17442843459150.jpeg
#   inflating: images/r17442943418210.jpeg
#   inflating: images/r17443043395810.jpeg
#   inflating: images/r17443143370380.jpeg
#   inflating: images/r17443243365530.jpeg
#   inflating: images/r17443343367550.jpeg
#   inflating: images/r17443443370300.jpeg
#   inflating: images/r17443543382250.jpeg
#   inflating: images/r17443643364020.jpeg
#   inflating: images/r17443743357980.jpeg
#   inflating: images/r17443843324310.jpeg
#   inflating: images/r17443943294290.jpeg
#   inflating: images/r17444043254140.jpeg
#   inflating: images/r17444143220340.jpeg
#   inflating: images/r17444243216200.jpeg
#   inflating: images/r17444343227920.jpeg
#   inflating: images/r17444443267820.jpeg
#   inflating: images/r17444543278770.jpeg
#   inflating: images/r17481741313280.jpeg
#   inflating: images/r17509740482540.jpeg
#   inflating: images/r17509840484370.jpeg
#   inflating: images/r17509940520870.jpeg
#   inflating: images/r17510040542650.jpeg
#   inflating: images/r17510140563580.jpeg
#   inflating: images/r17510240560400.jpeg
#   inflating: images/r17510340546600.jpeg
#   inflating: images/r17510440531300.jpeg
#   inflating: images/r17510540525280.jpeg
#   inflating: images/r17569738964880.jpeg
#   inflating: images/r17569838983850.jpeg
#   inflating: images/r17569939007060.jpeg
#   inflating: images/r17570039036660.jpeg
#   inflating: images/r17570139050850.jpeg
#   inflating: images/r17570239054280.jpeg
#   inflating: images/r17570339019650.jpeg
#   inflating: images/r17570438976480.jpeg
#   inflating: images/r17591238302930.jpeg
#   inflating: images/r17620836437750.jpeg
#   inflating: images/r17620936439580.jpeg
#   inflating: images/r17621036433260.jpeg
#   inflating: images/r17633135340530.jpeg
#   inflating: images/r17633235353430.jpeg
#   inflating: images/r17650634435060.jpeg
#   inflating: images/r17650734428170.jpeg
#   inflating: images/r17847221084190.jpeg
#   inflating: images/r17847321109740.jpeg
#   inflating: images/r17847421110710.jpeg
#   inflating: images/r17847521140510.jpeg
#   inflating: images/r17847621159310.jpeg
#   inflating: images/r17847721176780.jpeg
#   inflating: images/r17847821180660.jpeg
#   inflating: images/r17847921194720.jpeg
#   inflating: images/r17878218656640.jpeg
#   inflating: images/r17878318596060.jpeg
#   inflating: images/r17878418586740.jpeg
#   inflating: images/r17890817953320.jpeg
#   inflating: images/r17890917910410.jpeg
#   inflating: images/r17891017884980.jpeg
#   inflating: images/r17891117882540.jpeg
#   inflating: images/r17891217919960.jpeg
#   inflating: images/r17891317927340.jpeg
#   inflating: images/r17891417909360.jpeg
#   inflating: images/r17891517876360.jpeg
#   inflating: images/r17891617837890.jpeg
#   inflating: images/r17891717766020.jpeg
#   inflating: images/r17891817724250.jpeg
#   inflating: images/r17891917728730.jpeg
#   inflating: images/r17892017718810.jpeg
#   inflating: images/r17892117728470.jpeg
#   inflating: images/r17892217774860.jpeg
#   inflating: images/r17907117440340.jpeg
#   inflating: images/r17907217461320.jpeg
#   inflating: images/r17907317452240.jpeg
#   inflating: images/r17907417409370.jpeg
#   inflating: images/r17907517390730.jpeg
#   inflating: images/r17907617395270.jpeg
#   inflating: images/r17918416178550.jpeg
#   inflating: images/r17918516197080.jpeg
#   inflating: images/r17918616204410.jpeg
#   inflating: images/r17918716240260.jpeg
#   inflating: images/r17918816274780.jpeg
#   inflating: images/r17918916309720.jpeg
#   inflating: images/r17919016336090.jpeg
#   inflating: images/r17919116344110.jpeg
#   inflating: images/r17919216316640.jpeg
#   inflating: images/r17919316282980.jpeg
#   inflating: images/r17919416230010.jpeg
#   inflating: images/r17919516173700.jpeg
#   inflating: images/r17927815790120.jpeg
#   inflating: images/r17927915759680.jpeg
#   inflating: images/r17980311474720.jpeg
#   inflating: images/r17980411485250.jpeg
#   inflating: images/r17980511483800.jpeg
#   inflating: images/r17980611459300.jpeg
#   inflating: images/r17980711437490.jpeg
#   inflating: images/r17980811418410.jpeg
#   inflating: images/r17980911430600.jpeg
#   inflating: images/r17981011436790.jpeg
#   inflating: images/r17981111443860.jpeg
#   inflating: images/r17981211436380.jpeg
#   inflating: images/r17981311448290.jpeg
#   inflating: images/r17981411459620.jpeg
#   inflating: images/r17981511445240.jpeg
#   inflating: images/r17981611407550.jpeg
#   inflating: images/r17983911583040.jpeg
#   inflating: images/r17984011571220.jpeg
#   inflating: images/r17984111547530.jpeg
#   inflating: images/r17984211520340.jpeg
#   inflating: images/r17984311505840.jpeg
#   inflating: images/r17984411500560.jpeg
#   inflating: images/r17984511500290.jpeg
#   inflating: images/r17984611495610.jpeg
#   inflating: images/r17984711486860.jpeg
#   inflating: images/r17984811456890.jpeg
#   inflating: images/r17984911415920.jpeg
#   inflating: images/r17985011379430.jpeg
#   inflating: images/r17985111358650.jpeg
#   inflating: images/r17985211360120.jpeg
#   inflating: images/r17985311364280.jpeg
#   inflating: images/r17985411382680.jpeg
#   inflating: images/r17985511381610.jpeg
#   inflating: images/r17985611392850.jpeg
#   inflating: images/r17985711387470.jpeg
#   inflating: images/r17985811370020.jpeg
#   inflating: images/r17985911376220.jpeg
#   inflating: images/r17986011393820.jpeg
#   inflating: images/r17986111412270.jpeg
#   inflating: images/r17986211413860.jpeg
#   inflating: images/r17991211168240.jpeg
#   inflating: images/r17991311180460.jpeg
#   inflating: images/r17991411199280.jpeg
#   inflating: images/r17991511230620.jpeg
#   inflating: images/r17991611241620.jpeg
#   inflating: images/r17991711256590.jpeg
#   inflating: images/r17991811276340.jpeg
#   inflating: images/r17991911304490.jpeg
#   inflating: images/r17992011316220.jpeg
#   inflating: images/r17992111330310.jpeg
#   inflating: images/r17992211352620.jpeg
#   inflating: images/r17992311355420.jpeg
#   inflating: images/r17992411363310.jpeg
#   inflating: images/r17992511331250.jpeg
#    creating: masks/
#   inflating: masks/r16219069037040.png
#   inflating: masks/r16219168976000.png
#   inflating: masks/r16219268910540.png
#   inflating: masks/r16219368858940.png
#   inflating: masks/r16219468840110.png
#   inflating: masks/r16219568818820.png
#   inflating: masks/r16219668825490.png
#   inflating: masks/r16219768829010.png
#   inflating: masks/r16219868842610.png
#   inflating: masks/r16219968901180.png
#   inflating: masks/r16220068924700.png
#   inflating: masks/r16220168928920.png
#   inflating: masks/r16220268891070.png
#   inflating: masks/r16220368836770.png
#   inflating: masks/r16220468777280.png
#   inflating: masks/r16271868052300.png
#   inflating: masks/r16271968044680.png
#   inflating: masks/r16272068063050.png
#   inflating: masks/r16272168055620.png
#   inflating: masks/r16272268048110.png
#   inflating: masks/r16272368039380.png
#   inflating: masks/r16272468030270.png
#   inflating: masks/r16272568020360.png
#   inflating: masks/r16272668022140.png
#   inflating: masks/r16272768027480.png
#   inflating: masks/r16272868048060.png
#   inflating: masks/r16272968091130.png
#   inflating: masks/r16273068119390.png
#   inflating: masks/r16273168175070.png
#   inflating: masks/r16273268230490.png
#   inflating: masks/r16273368270120.png
#   inflating: masks/r16273468280610.png
#   inflating: masks/r16273568252280.png
#   inflating: masks/r16273668206670.png
#   inflating: masks/r16273768151640.png
#   inflating: masks/r16273868108470.png
#   inflating: masks/r16273968084080.png
#   inflating: masks/r16274068062510.png
#   inflating: masks/r16274168050640.png
#   inflating: masks/r16274268034350.png
#   inflating: masks/r16274368012530.png
#   inflating: masks/r16274467969630.png
#   inflating: masks/r16274567955650.png
#   inflating: masks/r16274667949910.png
#   inflating: masks/r16274767959340.png
#   inflating: masks/r16274867951230.png
#   inflating: masks/r16274967955390.png
#   inflating: masks/r16275067955140.png
#   inflating: masks/r16275167966110.png
#   inflating: masks/r16275267994810.png
#   inflating: masks/r16275368041110.png
#   inflating: masks/r16275468074400.png
#   inflating: masks/r16275568084270.png
#   inflating: masks/r17136458354500.png
#   inflating: masks/r17136558333950.png
#   inflating: masks/r17136658280820.png
#   inflating: masks/r17136758250230.png
#   inflating: masks/r17136858258640.png
#   inflating: masks/r17136958261380.png
#   inflating: masks/r17137058248100.png
#   inflating: masks/r17137158240330.png
#   inflating: masks/r17137258244460.png
#   inflating: masks/r17137358235650.png
#   inflating: masks/r17154358086040.png
#   inflating: masks/r17253450946200.png
#   inflating: masks/r17253550885830.png
#   inflating: masks/r17253650837230.png
#   inflating: masks/r17253750828620.png
#   inflating: masks/r17317746189830.png
#   inflating: masks/r17317846168890.png
#   inflating: masks/r17317946149190.png
#   inflating: masks/r17318046095120.png
#   inflating: masks/r17318146067720.png
#   inflating: masks/r17318246050470.png
#   inflating: masks/r17318346038420.png
#   inflating: masks/r17318446021830.png
#   inflating: masks/r17318546035810.png
#   inflating: masks/r17318646058340.png
#   inflating: masks/r17318746085700.png
#   inflating: masks/r17318846127960.png
#   inflating: masks/r17318946146980.png
#   inflating: masks/r17442743457510.png
#   inflating: masks/r17442843459150.png
#   inflating: masks/r17442943418210.png
#   inflating: masks/r17443043395810.png
#   inflating: masks/r17443143370380.png
#   inflating: masks/r17443243365530.png
#   inflating: masks/r17443343367550.png
#   inflating: masks/r17443443370300.png
#   inflating: masks/r17443543382250.png
#   inflating: masks/r17443643364020.png
#   inflating: masks/r17443743357980.png
#   inflating: masks/r17443843324310.png
#   inflating: masks/r17443943294290.png
#   inflating: masks/r17444043254140.png
#   inflating: masks/r17444143220340.png
#   inflating: masks/r17444243216200.png
#   inflating: masks/r17444343227920.png
#   inflating: masks/r17444443267820.png
#   inflating: masks/r17444543278770.png
#   inflating: masks/r17481741313280.png
#   inflating: masks/r17509740482540.png
#   inflating: masks/r17509840484370.png
#   inflating: masks/r17509940520870.png
#   inflating: masks/r17510040542650.png
#   inflating: masks/r17510140563580.png
#   inflating: masks/r17510240560400.png
#   inflating: masks/r17510340546600.png
#   inflating: masks/r17510440531300.png
#   inflating: masks/r17510540525280.png
#   inflating: masks/r17569738964880.png
#   inflating: masks/r17569838983850.png
#   inflating: masks/r17569939007060.png
#   inflating: masks/r17570039036660.png
#   inflating: masks/r17570139050850.png
#   inflating: masks/r17570239054280.png
#   inflating: masks/r17570339019650.png
#   inflating: masks/r17570438976480.png
#   inflating: masks/r17591238302930.png
#   inflating: masks/r17620836437750.png
#   inflating: masks/r17620936439580.png
#   inflating: masks/r17621036433260.png
#   inflating: masks/r17633135340530.png
#   inflating: masks/r17633235353430.png
#   inflating: masks/r17650634435060.png
#   inflating: masks/r17650734428170.png
#   inflating: masks/r17847221084190.png
#   inflating: masks/r17847321109740.png
#   inflating: masks/r17847421110710.png
#   inflating: masks/r17847521140510.png
#   inflating: masks/r17847621159310.png
#   inflating: masks/r17847721176780.png
#   inflating: masks/r17847821180660.png
#   inflating: masks/r17847921194720.png
#   inflating: masks/r17878218656640.png
#   inflating: masks/r17878318596060.png
#   inflating: masks/r17878418586740.png
#   inflating: masks/r17890817953320.png
#   inflating: masks/r17890917910410.png
#   inflating: masks/r17891017884980.png
#   inflating: masks/r17891117882540.png
#   inflating: masks/r17891217919960.png
#   inflating: masks/r17891317927340.png
#   inflating: masks/r17891417909360.png
#   inflating: masks/r17891517876360.png
#   inflating: masks/r17891617837890.png
#   inflating: masks/r17891717766020.png
#   inflating: masks/r17891817724250.png
#   inflating: masks/r17891917728730.png
#   inflating: masks/r17892017718810.png
#   inflating: masks/r17892117728470.png
#   inflating: masks/r17892217774860.png
#   inflating: masks/r17907117440340.png
#   inflating: masks/r17907217461320.png
#   inflating: masks/r17907317452240.png
#   inflating: masks/r17907417409370.png
#   inflating: masks/r17907517390730.png
#   inflating: masks/r17907617395270.png
#   inflating: masks/r17918416178550.png
#   inflating: masks/r17918516197080.png
#   inflating: masks/r17918616204410.png
#   inflating: masks/r17918716240260.png
#   inflating: masks/r17918816274780.png
#   inflating: masks/r17918916309720.png
#   inflating: masks/r17919016336090.png
#   inflating: masks/r17919116344110.png
#   inflating: masks/r17919216316640.png
#   inflating: masks/r17919316282980.png
#   inflating: masks/r17919416230010.png
#   inflating: masks/r17919516173700.png
#   inflating: masks/r17927815790120.png
#   inflating: masks/r17927915759680.png
#   inflating: masks/r17980311474720.png
#   inflating: masks/r17980411485250.png
#   inflating: masks/r17980511483800.png
#   inflating: masks/r17980611459300.png
#   inflating: masks/r17980711437490.png
#   inflating: masks/r17980811418410.png
#   inflating: masks/r17980911430600.png
#   inflating: masks/r17981011436790.png
#   inflating: masks/r17981111443860.png
#   inflating: masks/r17981211436380.png
#   inflating: masks/r17981311448290.png
#   inflating: masks/r17981411459620.png
#   inflating: masks/r17981511445240.png
#   inflating: masks/r17981611407550.png
#   inflating: masks/r17983911583040.png
#   inflating: masks/r17984011571220.png
#   inflating: masks/r17984111547530.png
#   inflating: masks/r17984211520340.png
#   inflating: masks/r17984311505840.png
#   inflating: masks/r17984411500560.png
#   inflating: masks/r17984511500290.png
#   inflating: masks/r17984611495610.png
#   inflating: masks/r17984711486860.png
#   inflating: masks/r17984811456890.png
#   inflating: masks/r17984911415920.png
#   inflating: masks/r17985011379430.png
#   inflating: masks/r17985111358650.png
#   inflating: masks/r17985211360120.png
#   inflating: masks/r17985311364280.png
#   inflating: masks/r17985411382680.png
#   inflating: masks/r17985511381610.png
#   inflating: masks/r17985611392850.png
#   inflating: masks/r17985711387470.png
#   inflating: masks/r17985811370020.png
#   inflating: masks/r17985911376220.png
#   inflating: masks/r17986011393820.png
#   inflating: masks/r17986111412270.png
#   inflating: masks/r17986211413860.png
#   inflating: masks/r17991211168240.png
#   inflating: masks/r17991311180460.png
#   inflating: masks/r17991411199280.png
#   inflating: masks/r17991511230620.png
#   inflating: masks/r17991611241620.png
#   inflating: masks/r17991711256590.png
#   inflating: masks/r17991811276340.png
#   inflating: masks/r17991911304490.png
#   inflating: masks/r17992011316220.png
#   inflating: masks/r17992111330310.png
#   inflating: masks/r17992211352620.png
#   inflating: masks/r17992311355420.png
#   inflating: masks/r17992411363310.png
#   inflating: masks/r17992511331250.png

# %%
mkdir data

# %%
# !mv ./images ./data
# !mv ./masks ./data

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ## Creating a TensorFlow Dataset
#
# Training on the entire CIHP dataset with 38,280 images takes a lot of time, hence we will be using
# a smaller subset of 200 images for training our model in this example.

# %%
def flip(image,mask):
    s = random.randint(0,10)
    model = lambda image:tf.image.flip_left_right(image)

    

    return model(image),model(mask)


# def zoom(image,mask):
#     s = random.randint(0,10)
#     model = tf.keras.Sequential([tf.keras.layers.RandomZoom(height_factor=(-0.4,-0.4),width_factor=(-0.4,-0.4),seed=s,fill_mode='nearest')])

#     return model(image),model(mask)

# def shift(image,mask):
#     s = random.randint(0,10)
#     model = tf.keras.Sequential([tf.keras.layers.RandomTranslation(height_factor=0.0,width_factor=0.4,seed=s,fill_mode='nearest')])

    return model(image),model(mask)

def augment(ds):
    # flip, zoom , translate horizontally
    flipped_ds  = ds.map(flip)
    # zoom_ds = ds.map(zoom)
    # shift_ds = ds.map(shift)

    # ds.concatenate(flipped_ds)
    # ds.concatenate(zoom_ds)
    # ds.concatenate(shift_ds)

    return flipped_ds

# %%
dataset = tf.data.Dataset.range(1, 6)
dataset2 = dataset.map(lambda x: x + 1)
list(dataset2.as_numpy_iterator())
# Out:
# [2, 3, 4, 5, 6]

# %%
import random
IMAGE_SIZE = 128
BATCH_SIZE = 4
NUM_CLASSES = 1
DATA_DIR = "./data"
NUM_TRAIN_IMAGES = 204
NUM_VAL_IMAGES = 20

train_images = sorted(glob(os.path.join(DATA_DIR, "images/*")))
random.shuffle(train_images,lambda:0.5)
train_images = train_images[:NUM_TRAIN_IMAGES]


train_masks = sorted(glob(os.path.join(DATA_DIR, "masks/*")))
random.shuffle(train_masks,lambda:0.5)
train_masks = train_masks[:NUM_TRAIN_IMAGES]



val_images = sorted(glob(os.path.join(DATA_DIR, "images/*")))
random.shuffle(val_images,lambda:0.5)
val_images = val_images[NUM_TRAIN_IMAGES : NUM_VAL_IMAGES + NUM_TRAIN_IMAGES]


val_masks = sorted(glob(os.path.join(DATA_DIR, "masks/*")))
random.shuffle(val_masks,lambda:0.5)
val_masks = val_masks[NUM_TRAIN_IMAGES : NUM_VAL_IMAGES + NUM_TRAIN_IMAGES]


def read_image(image_path, mask=False):
    image = tf.io.read_file(image_path)
    if mask:
        image = tf.image.decode_png(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, 1024],method='nearest')
        image = image/255
    else:
        image = tf.image.decode_jpeg(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, 1024])
        image = image /255
    return image


def load_data(image_list, mask_list):
    image = read_image(image_list)
    mask = read_image(mask_list, mask=True)
    return image, mask


def data_generator(image_list, mask_list):
    dataset = tf.data.Dataset.from_tensor_slices((image_list, mask_list))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    # flip = augment(dataset)
    fd = dataset.map(flip)

    dataset.concatenate(fd)
    dataset = dataset.shuffle(1000)
    dataset = dataset.batch(BATCH_SIZE)
    return dataset


train_dataset = data_generator(train_images, train_masks)
val_dataset = data_generator(val_images, val_masks)

print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)

# train_data_aug  = augment(train_dataset)
# print("Augmented Dataset:",train_data_aug)
# Out:
# Train Dataset: <BatchDataset shapes: ((None, 128, 1024, 3), (None, 128, 1024, 1)), types: (tf.float32, tf.float32)>
# Val Dataset: <BatchDataset shapes: ((None, 128, 1024, 3), (None, 128, 1024, 1)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## Building the DeepLabV3+ model
#
# DeepLabv3+ extends DeepLabv3 by adding an encoder-decoder structure. The encoder module
# processes multiscale contextual information by applying dilated convolution at multiple
# scales, while the decoder module refines the segmentation results along object boundaries.
#
# ![](https://github.com/lattice-ai/DeepLabV3-Plus/raw/master/assets/deeplabv3_plus_diagram.png)
#
# **Dilated convolution:** With dilated convolution, as we go deeper in the network, we can keep the
# stride constant but with larger field-of-view without increasing the number of parameters
# or the amount of computation. Besides, it enables larger output feature maps, which is
# useful for semantic segmentation.
#
# The reason for using **Dilated Spatial Pyramid Pooling** is that it was shown that as the
# sampling rate becomes larger, the number of valid filter weights (i.e., weights that
# are applied to the valid feature region, instead of padded zeros) becomes smaller.

# %%
def convolution_block(
    block_input,
    num_filters=256,
    kernel_size=3,
    dilation_rate=1,
    padding="same",
    use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)


def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

# %% [markdown]
# The encoder features are first bilinearly upsampled by a factor 4, and then
# concatenated with the corresponding low-level features from the network backbone that
# have the same spatial resolution. For this example, we
# use a ResNet50 pretrained on ImageNet as the backbone model, and we use
# the low-level features from the `conv4_block6_2_relu` block of the backbone.

# %%
def DeeplabV3Plus(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, 1024, 3))
    resnet50 = keras.applications.ResNet50(
        weights="imagenet", include_top=False, input_tensor=model_input
    )
    resnet50.trainable = True
    x = resnet50.get_layer("conv4_block6_2_relu").output
    x = DilatedSpatialPyramidPooling(x)

    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], 1024 // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], 1024 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same",activation='sigmoid')(x)
    return keras.Model(inputs=model_input, outputs=model_output)

def add_sample_weights(image, label):
  # The weights for each class, with the constraint that:
  #     sum(class_weights) == 1.0
  class_weights = tf.constant([100.0, 100000000000.0,10000000000.0])
  class_weights = class_weights/tf.reduce_sum(class_weights)

  # Create an image of `sample_weights` by using the label at each pixel as an 
  # index into the `class weights` .
  sample_weights = tf.gather(class_weights, indices=tf.cast(label, tf.int32))

  return image, label, sample_weights

model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 1024, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 134, 1030, 3) 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 64, 512, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 64, 512, 64)  256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 64, 512, 64)  0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 66, 514, 64)  0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 32, 256, 64)  0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 32, 256, 64)  4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 32, 256, 64)  256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 32, 256, 64)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 32, 256, 64)  36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 32, 256, 64)  256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 32, 256, 64)  0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 32, 256, 256) 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 32, 256, 256) 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 32, 256, 256) 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 32, 256, 256) 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 32, 256, 256) 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 32, 256, 256) 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 32, 256, 64)  16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 32, 256, 64)  256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 32, 256, 64)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 32, 256, 64)  36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 32, 256, 64)  256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 32, 256, 64)  0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 32, 256, 256) 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 32, 256, 256) 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 32, 256, 256) 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 32, 256, 256) 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 32, 256, 64)  16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 32, 256, 64)  256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 32, 256, 64)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 32, 256, 64)  36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 32, 256, 64)  256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 32, 256, 64)  0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 32, 256, 256) 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 32, 256, 256) 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 32, 256, 256) 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 32, 256, 256) 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 16, 128, 128) 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 16, 128, 128) 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 16, 128, 128) 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 16, 128, 128) 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 16, 128, 512) 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 16, 128, 512) 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 16, 128, 512) 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 16, 128, 512) 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 16, 128, 512) 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 16, 128, 512) 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 16, 128, 128) 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 16, 128, 128) 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 16, 128, 128) 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 16, 128, 128) 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 16, 128, 512) 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 16, 128, 512) 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 16, 128, 512) 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 16, 128, 512) 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 16, 128, 128) 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 16, 128, 128) 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 16, 128, 128) 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 16, 128, 128) 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 16, 128, 512) 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 16, 128, 512) 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 16, 128, 512) 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 16, 128, 512) 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 16, 128, 128) 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 16, 128, 128) 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 16, 128, 128) 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 16, 128, 128) 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 16, 128, 128) 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 16, 128, 512) 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 16, 128, 512) 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 16, 128, 512) 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 16, 128, 512) 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 8, 64, 256)   131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 8, 64, 256)   0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 8, 64, 256)   590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 8, 64, 256)   0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 8, 64, 1024)  525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 8, 64, 1024)  263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 8, 64, 1024)  4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 8, 64, 1024)  4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 8, 64, 1024)  0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 8, 64, 1024)  0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 8, 64, 256)   262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 8, 64, 256)   0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 8, 64, 256)   590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 8, 64, 256)   0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 8, 64, 1024)  263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 8, 64, 1024)  4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 8, 64, 1024)  0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 8, 64, 1024)  0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 8, 64, 256)   262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 8, 64, 256)   0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 8, 64, 256)   590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 8, 64, 256)   0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 8, 64, 1024)  263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 8, 64, 1024)  4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 8, 64, 1024)  0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 8, 64, 1024)  0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 8, 64, 256)   262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 8, 64, 256)   0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 8, 64, 256)   590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 8, 64, 256)   0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 8, 64, 1024)  263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 8, 64, 1024)  4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 8, 64, 1024)  0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 8, 64, 1024)  0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 8, 64, 256)   262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 8, 64, 256)   0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 8, 64, 256)   590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 8, 64, 256)   0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 8, 64, 1024)  263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 8, 64, 1024)  4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 8, 64, 1024)  0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 8, 64, 1024)  0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 8, 64, 256)   262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 8, 64, 256)   0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 8, 64, 256)   590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 8, 64, 256)   1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 8, 64, 256)   0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 256)    0           conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 1, 256)    65792       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1, 1, 256)    1024        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 64, 256)   65536       conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 64, 256)   589824      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 64, 256)   589824      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 64, 256)   589824      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 1, 1, 256)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 64, 256)   1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 64, 256)   1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 64, 256)   1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 64, 256)   1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 64, 256)   0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 8, 64, 256)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 8, 64, 256)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 8, 64, 256)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 8, 64, 256)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 64, 1280)  0           up_sampling2d[0][0]
#                                                                  tf.nn.relu_1[0][0]
#                                                                  tf.nn.relu_2[0][0]
#                                                                  tf.nn.relu_3[0][0]
#                                                                  tf.nn.relu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 64, 256)   327680      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 64, 256)   1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 256, 48)  3072        conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_5 (TFOpLambda)       (None, 8, 64, 256)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 256, 48)  192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 256, 256) 0           tf.nn.relu_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_6 (TFOpLambda)       (None, 32, 256, 48)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 256, 304) 0           up_sampling2d_1[0][0]
#                                                                  tf.nn.relu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 256, 256) 700416      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 256, 256) 1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_7 (TFOpLambda)       (None, 32, 256, 256) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 256, 256) 589824      tf.nn.relu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 256, 256) 1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_8 (TFOpLambda)       (None, 32, 256, 256) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 1024, 25 0           tf.nn.relu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 1024, 1) 257         up_sampling2d_2[0][0]
# ==================================================================================================
# Total params: 11,852,353
# Trainable params: 11,819,617
# Non-trainable params: 32,736
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training
#
# We train the model using sparse categorical crossentropy as the loss function, and
# Adam as the optimizer.

# %%
path = 'r16219069037040.png'
image = tf.io.read_file(path)
image = tf.image.decode_png(image, channels=1)
image.set_shape([None, None, 1])
image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE],method='nearest')
# image = image/255

# np.unique(image)
image.shape
# Out:
# TensorShape([512, 512, 1])

# %%
# model.reset_states()
ckpt_cb = tf.keras.callbacks.ModelCheckpoint('./checkpoints/aug_model_free/95.h5',monitor='accuracy',save_weights_only=True)
# model.load_weights('./checkpoints/aug_model_free/acc935.h5')
es = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',min_delta=0.00001,patience=150,verbose=1,restore_best_weights=True)
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
loss = keras.losses.BinaryCrossentropy()
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.00001),
    loss=loss,
    metrics=["accuracy"],
)
model
history = model.fit(train_dataset.map(add_sample_weights), validation_data=val_dataset.map(add_sample_weights), epochs=1200,callbacks=[ckpt_cb,es])

plt.plot(history.history["loss"])
plt.title("Training Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["accuracy"])
plt.title("Training Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_loss"])
plt.title("Validation Loss")
plt.ylabel("val_loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_accuracy"])
plt.title("Validation Accuracy")
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.show()
# Out:
# Epoch 1/1200
# 51/51 [==============================] - 22s 330ms/step - loss: 6.5425e-10 - accuracy: 0.9447 - val_loss: 0.0035 - val_accuracy: 0.9390
# Epoch 2/1200
# 51/51 [==============================] - 16s 314ms/step - loss: 6.3847e-10 - accuracy: 0.9452 - val_loss: 0.0035 - val_accuracy: 0.9391
# Epoch 3/1200
# 51/51 [==============================] - 16s 314ms/step - loss: 6.7718e-10 - accuracy: 0.9450 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 4/1200
# 51/51 [==============================] - 16s 315ms/step - loss: 6.6719e-10 - accuracy: 0.9425 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 5/1200
# 51/51 [==============================] - 16s 315ms/step - loss: 6.6427e-10 - accuracy: 0.9431 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 6/1200
# 51/51 [==============================] - 16s 316ms/step - loss: 6.6352e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 7/1200
# 51/51 [==============================] - 16s 315ms/step - loss: 6.9448e-10 - accuracy: 0.9422 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 8/1200
# 51/51 [==============================] - 16s 316ms/step - loss: 6.5312e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9383
# Epoch 9/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.6391e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9383
# Epoch 10/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.5719e-10 - accuracy: 0.9443 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 11/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.6430e-10 - accuracy: 0.9436 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 12/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.5379e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 13/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.7078e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 14/1200
# 51/51 [==============================] - 17s 318ms/step - loss: 6.9564e-10 - accuracy: 0.9422 - val_loss: 0.0035 - val_accuracy: 0.9389
# Epoch 15/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.5884e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 16/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.5437e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 17/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.5686e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 18/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.5337e-10 - accuracy: 0.9448 - val_loss: 0.0035 - val_accuracy: 0.9389
# Epoch 19/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.5510e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9389
# Epoch 20/1200
# 51/51 [==============================] - 16s 317ms/step - loss: 6.5356e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 21/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.7060e-10 - accuracy: 0.9429 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 22/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.6452e-10 - accuracy: 0.9444 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 23/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.7066e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 24/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.7494e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 25/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6827e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 26/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6000e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 27/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6863e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 28/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6750e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 29/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6305e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 30/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7051e-10 - accuracy: 0.9436 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 31/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6094e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 32/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5541e-10 - accuracy: 0.9444 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 33/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6801e-10 - accuracy: 0.9429 - val_loss: 0.0034 - val_accuracy: 0.9384
# Epoch 34/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5885e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 35/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7311e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 36/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6028e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 37/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5953e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 38/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.5376e-10 - accuracy: 0.9442 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 39/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5730e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 40/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.4761e-10 - accuracy: 0.9454 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 41/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6692e-10 - accuracy: 0.9436 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 42/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7037e-10 - accuracy: 0.9434 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 43/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6213e-10 - accuracy: 0.9444 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 44/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5967e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 45/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5389e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 46/1200
# 51/51 [==============================] - 17s 325ms/step - loss: 6.6852e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 47/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7592e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9381
# Epoch 48/1200
# 51/51 [==============================] - 17s 329ms/step - loss: 6.5795e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9383
# Epoch 49/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6390e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 50/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6348e-10 - accuracy: 0.9435 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 51/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6275e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 52/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7946e-10 - accuracy: 0.9426 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 53/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6547e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 54/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.4659e-10 - accuracy: 0.9452 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 55/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7289e-10 - accuracy: 0.9430 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 56/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5572e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 57/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.7112e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 58/1200
# 51/51 [==============================] - 17s 323ms/step - loss: 6.5593e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 59/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.4788e-10 - accuracy: 0.9441 - val_loss: 0.0034 - val_accuracy: 0.9384
# Epoch 60/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5720e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 61/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7994e-10 - accuracy: 0.9427 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 62/1200
# 51/51 [==============================] - 16s 318ms/step - loss: 6.5419e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 63/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7169e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 64/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.4687e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 65/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.4628e-10 - accuracy: 0.9450 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 66/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6141e-10 - accuracy: 0.9429 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 67/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5547e-10 - accuracy: 0.9447 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 68/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7493e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 69/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6731e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 70/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6025e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 71/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6773e-10 - accuracy: 0.9447 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 72/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.4730e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 73/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6595e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 74/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.8488e-10 - accuracy: 0.9435 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 75/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.3261e-10 - accuracy: 0.9462 - val_loss: 0.0034 - val_accuracy: 0.9384
# Epoch 76/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5959e-10 - accuracy: 0.9442 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 77/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6467e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 78/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5310e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 79/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6492e-10 - accuracy: 0.9430 - val_loss: 0.0035 - val_accuracy: 0.9389
# Epoch 80/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.8453e-10 - accuracy: 0.9425 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 81/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5418e-10 - accuracy: 0.9448 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 82/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6975e-10 - accuracy: 0.9435 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 83/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.4451e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 84/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.7710e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 85/1200
# 51/51 [==============================] - 17s 328ms/step - loss: 6.7556e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 86/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6278e-10 - accuracy: 0.9435 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 87/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6695e-10 - accuracy: 0.9427 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 88/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5852e-10 - accuracy: 0.9436 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 89/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5372e-10 - accuracy: 0.9447 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 90/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6628e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 91/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7732e-10 - accuracy: 0.9413 - val_loss: 0.0035 - val_accuracy: 0.9383
# Epoch 92/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6743e-10 - accuracy: 0.9428 - val_loss: 0.0034 - val_accuracy: 0.9384
# Epoch 93/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6196e-10 - accuracy: 0.9444 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 94/1200
# 51/51 [==============================] - 17s 321ms/step - loss: 6.6724e-10 - accuracy: 0.9425 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 95/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6400e-10 - accuracy: 0.9442 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 96/1200
# 51/51 [==============================] - 17s 321ms/step - loss: 6.5570e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 97/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5117e-10 - accuracy: 0.9451 - val_loss: 0.0035 - val_accuracy: 0.9389
# Epoch 98/1200
# 51/51 [==============================] - 17s 325ms/step - loss: 6.5329e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 99/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5099e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9389
# Epoch 100/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.4662e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 101/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5339e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 102/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.3567e-10 - accuracy: 0.9460 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 103/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6335e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 104/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6545e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 105/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.4387e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 106/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5373e-10 - accuracy: 0.9443 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 107/1200
# 51/51 [==============================] - 17s 324ms/step - loss: 6.5326e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9390
# Epoch 108/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6139e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 109/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.8742e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 110/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.4539e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 111/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7382e-10 - accuracy: 0.9434 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 112/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5920e-10 - accuracy: 0.9450 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 113/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.8482e-10 - accuracy: 0.9426 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 114/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.4890e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 115/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6786e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9384
# Epoch 116/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.4827e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 117/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6999e-10 - accuracy: 0.9429 - val_loss: 0.0034 - val_accuracy: 0.9386
# Epoch 118/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5211e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 119/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5398e-10 - accuracy: 0.9443 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 120/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5721e-10 - accuracy: 0.9439 - val_loss: 0.0034 - val_accuracy: 0.9385
# Epoch 121/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.9428e-10 - accuracy: 0.9417 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 122/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6828e-10 - accuracy: 0.9431 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 123/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6948e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 124/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5871e-10 - accuracy: 0.9448 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 125/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5611e-10 - accuracy: 0.9440 - val_loss: 0.0034 - val_accuracy: 0.9386
# Epoch 126/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.6087e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 127/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5958e-10 - accuracy: 0.9439 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 128/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5144e-10 - accuracy: 0.9449 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 129/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7140e-10 - accuracy: 0.9440 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 130/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5763e-10 - accuracy: 0.9443 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 131/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6319e-10 - accuracy: 0.9443 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 132/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5565e-10 - accuracy: 0.9442 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 133/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6081e-10 - accuracy: 0.9446 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 134/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5044e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 135/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5777e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 136/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6452e-10 - accuracy: 0.9442 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 137/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5782e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 138/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6742e-10 - accuracy: 0.9448 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 139/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5085e-10 - accuracy: 0.9447 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 140/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.8458e-10 - accuracy: 0.9431 - val_loss: 0.0035 - val_accuracy: 0.9388
# Epoch 141/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.5967e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 142/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.8474e-10 - accuracy: 0.9428 - val_loss: 0.0034 - val_accuracy: 0.9383
# Epoch 143/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7478e-10 - accuracy: 0.9445 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 144/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7503e-10 - accuracy: 0.9422 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 145/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5309e-10 - accuracy: 0.9435 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 146/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6253e-10 - accuracy: 0.9438 - val_loss: 0.0035 - val_accuracy: 0.9387
# Epoch 147/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.7757e-10 - accuracy: 0.9423 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 148/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.8878e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 149/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6019e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9386
# Epoch 150/1200
# 51/51 [==============================] - 17s 330ms/step - loss: 6.6855e-10 - accuracy: 0.9437 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 151/1200
# 51/51 [==============================] - 17s 319ms/step - loss: 6.5408e-10 - accuracy: 0.9441 - val_loss: 0.0035 - val_accuracy: 0.9385
# Epoch 152/1200
# 51/51 [==============================] - 17s 320ms/step - loss: 6.6184e-10 - accuracy: 0.9433 - val_loss: 0.0035 - val_accuracy: 0.9386
# Restoring model weights from the end of the best epoch.
# Epoch 00152: early stopping

# %%
model.load_weights('./checkpoints/aug_model_free/acc945.h5')

# %%
def cb(epoch):
    if epoch==0:
        return 1e-10
    return 1e-10*(10**epoch)
lrs = tf.keras.callbacks.LearningRateScheduler(cb)

history = model.fit(train_dataset.map(add_sample_weights), validation_data=val_dataset.map(add_sample_weights), epochs=10,callbacks=[lrs])

plt.semilogx(history.history['lr'],history.history['loss'])
# Out:
# Epoch 1/10
# 51/51 [==============================] - 17s 336ms/step - loss: 2.1251e-09 - accuracy: 0.8075 - val_loss: 3.5831e-09 - val_accuracy: 0.7966
# Epoch 2/10
# 51/51 [==============================] - 16s 320ms/step - loss: 2.1476e-09 - accuracy: 0.8080 - val_loss: 3.5774e-09 - val_accuracy: 0.7967
# Epoch 3/10
# 51/51 [==============================] - 16s 321ms/step - loss: 2.1428e-09 - accuracy: 0.8079 - val_loss: 3.5920e-09 - val_accuracy: 0.7975
# Epoch 4/10
# 51/51 [==============================] - 17s 322ms/step - loss: 2.1657e-09 - accuracy: 0.8085 - val_loss: 3.5821e-09 - val_accuracy: 0.7974
# Epoch 5/10
# 51/51 [==============================] - 17s 322ms/step - loss: 2.1121e-09 - accuracy: 0.8085 - val_loss: 3.5893e-09 - val_accuracy: 0.7972
# Epoch 6/10
# 51/51 [==============================] - 17s 323ms/step - loss: 2.2104e-09 - accuracy: 0.8085 - val_loss: 3.5964e-09 - val_accuracy: 0.7975
# Epoch 7/10
# 51/51 [==============================] - 17s 323ms/step - loss: 2.2493e-09 - accuracy: 0.8084 - val_loss: 3.5797e-09 - val_accuracy: 0.7974
# Epoch 8/10
# 51/51 [==============================] - 17s 324ms/step - loss: 2.1393e-09 - accuracy: 0.8081 - val_loss: 3.4960e-09 - val_accuracy: 0.7973
# Epoch 9/10
# 51/51 [==============================] - 17s 326ms/step - loss: 2.0948e-09 - accuracy: 0.8091 - val_loss: 3.3516e-09 - val_accuracy: 0.7969
# Epoch 10/10
# 51/51 [==============================] - 17s 325ms/step - loss: 2.1494e-09 - accuracy: 0.8113 - val_loss: 2.8128e-09 - val_accuracy: 0.7644

# %%
history = model.fit(train_dataset.map(add_sample_weights), validation_data=val_dataset.map(add_sample_weights), epochs=500,callbacks=[ckpt_cb])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 17s 329ms/step - loss: 3.0332e-09 - accuracy: 0.7398 - val_loss: 5.6332e-09 - val_accuracy: 0.7044
# Epoch 2/100
# 51/51 [==============================] - 17s 327ms/step - loss: 3.0310e-09 - accuracy: 0.7399 - val_loss: 5.6363e-09 - val_accuracy: 0.7047
# Epoch 3/100
# 51/51 [==============================] - 17s 332ms/step - loss: 3.0288e-09 - accuracy: 0.7401 - val_loss: 5.6388e-09 - val_accuracy: 0.7050
# Epoch 4/100
# 51/51 [==============================] - 17s 328ms/step - loss: 3.0266e-09 - accuracy: 0.7402 - val_loss: 5.6427e-09 - val_accuracy: 0.7053
# Epoch 5/100
# 51/51 [==============================] - 17s 328ms/step - loss: 3.0245e-09 - accuracy: 0.7404 - val_loss: 5.6465e-09 - val_accuracy: 0.7056
# Epoch 6/100
# 51/51 [==============================] - 17s 327ms/step - loss: 3.0223e-09 - accuracy: 0.7405 - val_loss: 5.6504e-09 - val_accuracy: 0.7059
# Epoch 7/100
# 51/51 [==============================] - 17s 327ms/step - loss: 3.0202e-09 - accuracy: 0.7407 - val_loss: 5.6537e-09 - val_accuracy: 0.7063
# Epoch 8/100
# 51/51 [==============================] - 17s 328ms/step - loss: 3.0181e-09 - accuracy: 0.7409 - val_loss: 5.6574e-09 - val_accuracy: 0.7066
# Epoch 9/100
# 51/51 [==============================] - 17s 329ms/step - loss: 3.0159e-09 - accuracy: 0.7410 - val_loss: 5.6619e-09 - val_accuracy: 0.7069
# Epoch 10/100
# 51/51 [==============================] - 17s 329ms/step - loss: 3.0138e-09 - accuracy: 0.7412 - val_loss: 5.6674e-09 - val_accuracy: 0.7072
# Epoch 11/100
# 51/51 [==============================] - 17s 329ms/step - loss: 3.0117e-09 - accuracy: 0.7413 - val_loss: 5.6712e-09 - val_accuracy: 0.7075
# Epoch 12/100
# 51/51 [==============================] - 17s 330ms/step - loss: 3.0096e-09 - accuracy: 0.7415 - val_loss: 5.6750e-09 - val_accuracy: 0.7078
# Epoch 13/100
# 51/51 [==============================] - 17s 330ms/step - loss: 3.0075e-09 - accuracy: 0.7416 - val_loss: 5.6797e-09 - val_accuracy: 0.7081
# Epoch 14/100
# 51/51 [==============================] - 17s 331ms/step - loss: 3.0055e-09 - accuracy: 0.7418 - val_loss: 5.6854e-09 - val_accuracy: 0.7085
# Epoch 15/100
# 51/51 [==============================] - 17s 330ms/step - loss: 3.0034e-09 - accuracy: 0.7419 - val_loss: 5.6912e-09 - val_accuracy: 0.7088
# Epoch 16/100
# 51/51 [==============================] - 17s 330ms/step - loss: 3.0013e-09 - accuracy: 0.7421 - val_loss: 5.6960e-09 - val_accuracy: 0.7091
# Epoch 17/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9993e-09 - accuracy: 0.7422 - val_loss: 5.7009e-09 - val_accuracy: 0.7095
# Epoch 18/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9972e-09 - accuracy: 0.7424 - val_loss: 5.7069e-09 - val_accuracy: 0.7098
# Epoch 19/100
# 51/51 [==============================] - 17s 330ms/step - loss: 2.9952e-09 - accuracy: 0.7425 - val_loss: 5.7127e-09 - val_accuracy: 0.7101
# Epoch 20/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9932e-09 - accuracy: 0.7427 - val_loss: 5.7208e-09 - val_accuracy: 0.7104
# Epoch 21/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9911e-09 - accuracy: 0.7429 - val_loss: 5.7267e-09 - val_accuracy: 0.7108
# Epoch 22/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9891e-09 - accuracy: 0.7430 - val_loss: 5.7329e-09 - val_accuracy: 0.7111
# Epoch 23/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9871e-09 - accuracy: 0.7432 - val_loss: 5.7382e-09 - val_accuracy: 0.7114
# Epoch 24/100
# 51/51 [==============================] - 17s 335ms/step - loss: 2.9851e-09 - accuracy: 0.7433 - val_loss: 5.7446e-09 - val_accuracy: 0.7117
# Epoch 25/100
# 51/51 [==============================] - 17s 330ms/step - loss: 2.9831e-09 - accuracy: 0.7435 - val_loss: 5.7503e-09 - val_accuracy: 0.7121
# Epoch 26/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9811e-09 - accuracy: 0.7436 - val_loss: 5.7568e-09 - val_accuracy: 0.7124
# Epoch 27/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9791e-09 - accuracy: 0.7438 - val_loss: 5.7623e-09 - val_accuracy: 0.7127
# Epoch 28/100
# 51/51 [==============================] - 17s 337ms/step - loss: 2.9772e-09 - accuracy: 0.7439 - val_loss: 5.7694e-09 - val_accuracy: 0.7131
# Epoch 29/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9752e-09 - accuracy: 0.7441 - val_loss: 5.7743e-09 - val_accuracy: 0.7134
# Epoch 30/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9732e-09 - accuracy: 0.7442 - val_loss: 5.7826e-09 - val_accuracy: 0.7138
# Epoch 31/100
# 51/51 [==============================] - 17s 330ms/step - loss: 2.9713e-09 - accuracy: 0.7444 - val_loss: 5.7884e-09 - val_accuracy: 0.7141
# Epoch 32/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9693e-09 - accuracy: 0.7445 - val_loss: 5.7947e-09 - val_accuracy: 0.7144
# Epoch 33/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9674e-09 - accuracy: 0.7447 - val_loss: 5.8026e-09 - val_accuracy: 0.7148
# Epoch 34/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9654e-09 - accuracy: 0.7448 - val_loss: 5.8095e-09 - val_accuracy: 0.7151
# Epoch 35/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9635e-09 - accuracy: 0.7450 - val_loss: 5.8155e-09 - val_accuracy: 0.7154
# Epoch 36/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9615e-09 - accuracy: 0.7451 - val_loss: 5.8234e-09 - val_accuracy: 0.7158
# Epoch 37/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9596e-09 - accuracy: 0.7453 - val_loss: 5.8332e-09 - val_accuracy: 0.7161
# Epoch 38/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9577e-09 - accuracy: 0.7454 - val_loss: 5.8402e-09 - val_accuracy: 0.7164
# Epoch 39/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9558e-09 - accuracy: 0.7456 - val_loss: 5.8484e-09 - val_accuracy: 0.7167
# Epoch 40/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9539e-09 - accuracy: 0.7457 - val_loss: 5.8547e-09 - val_accuracy: 0.7171
# Epoch 41/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9520e-09 - accuracy: 0.7459 - val_loss: 5.8625e-09 - val_accuracy: 0.7174
# Epoch 42/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9501e-09 - accuracy: 0.7460 - val_loss: 5.8695e-09 - val_accuracy: 0.7178
# Epoch 43/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9482e-09 - accuracy: 0.7462 - val_loss: 5.8767e-09 - val_accuracy: 0.7181
# Epoch 44/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9463e-09 - accuracy: 0.7463 - val_loss: 5.8840e-09 - val_accuracy: 0.7185
# Epoch 45/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9444e-09 - accuracy: 0.7465 - val_loss: 5.8904e-09 - val_accuracy: 0.7188
# Epoch 46/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9425e-09 - accuracy: 0.7466 - val_loss: 5.8975e-09 - val_accuracy: 0.7191
# Epoch 47/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9406e-09 - accuracy: 0.7468 - val_loss: 5.9047e-09 - val_accuracy: 0.7194
# Epoch 48/100
# 51/51 [==============================] - 17s 337ms/step - loss: 2.9387e-09 - accuracy: 0.7469 - val_loss: 5.9114e-09 - val_accuracy: 0.7197
# Epoch 49/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9368e-09 - accuracy: 0.7471 - val_loss: 5.9190e-09 - val_accuracy: 0.7200
# Epoch 50/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9349e-09 - accuracy: 0.7472 - val_loss: 5.9264e-09 - val_accuracy: 0.7203
# Epoch 51/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9331e-09 - accuracy: 0.7474 - val_loss: 5.9347e-09 - val_accuracy: 0.7206
# Epoch 52/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9312e-09 - accuracy: 0.7475 - val_loss: 5.9431e-09 - val_accuracy: 0.7209
# Epoch 53/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9293e-09 - accuracy: 0.7476 - val_loss: 5.9520e-09 - val_accuracy: 0.7212
# Epoch 54/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9274e-09 - accuracy: 0.7478 - val_loss: 5.9608e-09 - val_accuracy: 0.7215
# Epoch 55/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9256e-09 - accuracy: 0.7479 - val_loss: 5.9691e-09 - val_accuracy: 0.7218
# Epoch 56/100
# 51/51 [==============================] - 17s 341ms/step - loss: 2.9237e-09 - accuracy: 0.7481 - val_loss: 5.9808e-09 - val_accuracy: 0.7221
# Epoch 57/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9218e-09 - accuracy: 0.7482 - val_loss: 5.9888e-09 - val_accuracy: 0.7224
# Epoch 58/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.9199e-09 - accuracy: 0.7484 - val_loss: 5.9975e-09 - val_accuracy: 0.7227
# Epoch 59/100
# 51/51 [==============================] - 17s 333ms/step - loss: 2.9181e-09 - accuracy: 0.7485 - val_loss: 6.0047e-09 - val_accuracy: 0.7230
# Epoch 60/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9162e-09 - accuracy: 0.7487 - val_loss: 6.0142e-09 - val_accuracy: 0.7233
# Epoch 61/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9144e-09 - accuracy: 0.7488 - val_loss: 6.0221e-09 - val_accuracy: 0.7236
# Epoch 62/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9125e-09 - accuracy: 0.7489 - val_loss: 6.0322e-09 - val_accuracy: 0.7239
# Epoch 63/100
# 51/51 [==============================] - 17s 333ms/step - loss: 2.9107e-09 - accuracy: 0.7491 - val_loss: 6.0404e-09 - val_accuracy: 0.7242
# Epoch 64/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9088e-09 - accuracy: 0.7492 - val_loss: 6.0481e-09 - val_accuracy: 0.7245
# Epoch 65/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9070e-09 - accuracy: 0.7494 - val_loss: 6.0575e-09 - val_accuracy: 0.7248
# Epoch 66/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9051e-09 - accuracy: 0.7495 - val_loss: 6.0668e-09 - val_accuracy: 0.7251
# Epoch 67/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9033e-09 - accuracy: 0.7497 - val_loss: 6.0782e-09 - val_accuracy: 0.7254
# Epoch 68/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.9014e-09 - accuracy: 0.7498 - val_loss: 6.0861e-09 - val_accuracy: 0.7257
# Epoch 69/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8996e-09 - accuracy: 0.7500 - val_loss: 6.0956e-09 - val_accuracy: 0.7261
# Epoch 70/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8977e-09 - accuracy: 0.7501 - val_loss: 6.1037e-09 - val_accuracy: 0.7263
# Epoch 71/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8959e-09 - accuracy: 0.7502 - val_loss: 6.1139e-09 - val_accuracy: 0.7266
# Epoch 72/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8941e-09 - accuracy: 0.7504 - val_loss: 6.1209e-09 - val_accuracy: 0.7269
# Epoch 73/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8922e-09 - accuracy: 0.7505 - val_loss: 6.1299e-09 - val_accuracy: 0.7273
# Epoch 74/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8904e-09 - accuracy: 0.7507 - val_loss: 6.1391e-09 - val_accuracy: 0.7276
# Epoch 75/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8886e-09 - accuracy: 0.7508 - val_loss: 6.1474e-09 - val_accuracy: 0.7278
# Epoch 76/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8868e-09 - accuracy: 0.7509 - val_loss: 6.1571e-09 - val_accuracy: 0.7281
# Epoch 77/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.8850e-09 - accuracy: 0.7511 - val_loss: 6.1689e-09 - val_accuracy: 0.7284
# Epoch 78/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8831e-09 - accuracy: 0.7512 - val_loss: 6.1775e-09 - val_accuracy: 0.7287
# Epoch 79/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8813e-09 - accuracy: 0.7514 - val_loss: 6.1874e-09 - val_accuracy: 0.7290
# Epoch 80/100
# 51/51 [==============================] - 17s 333ms/step - loss: 2.8795e-09 - accuracy: 0.7515 - val_loss: 6.1981e-09 - val_accuracy: 0.7293
# Epoch 81/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8777e-09 - accuracy: 0.7516 - val_loss: 6.2093e-09 - val_accuracy: 0.7296
# Epoch 82/100
# 51/51 [==============================] - 17s 333ms/step - loss: 2.8759e-09 - accuracy: 0.7518 - val_loss: 6.2185e-09 - val_accuracy: 0.7299
# Epoch 83/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8741e-09 - accuracy: 0.7519 - val_loss: 6.2318e-09 - val_accuracy: 0.7301
# Epoch 84/100
# 51/51 [==============================] - 17s 333ms/step - loss: 2.8723e-09 - accuracy: 0.7520 - val_loss: 6.2428e-09 - val_accuracy: 0.7304
# Epoch 85/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.8705e-09 - accuracy: 0.7522 - val_loss: 6.2536e-09 - val_accuracy: 0.7307
# Epoch 86/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8687e-09 - accuracy: 0.7523 - val_loss: 6.2645e-09 - val_accuracy: 0.7310
# Epoch 87/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8669e-09 - accuracy: 0.7524 - val_loss: 6.2770e-09 - val_accuracy: 0.7313
# Epoch 88/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8651e-09 - accuracy: 0.7526 - val_loss: 6.2864e-09 - val_accuracy: 0.7317
# Epoch 89/100
# 51/51 [==============================] - 17s 333ms/step - loss: 2.8633e-09 - accuracy: 0.7527 - val_loss: 6.3001e-09 - val_accuracy: 0.7320
# Epoch 90/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8615e-09 - accuracy: 0.7529 - val_loss: 6.3084e-09 - val_accuracy: 0.7323
# Epoch 91/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8597e-09 - accuracy: 0.7530 - val_loss: 6.3204e-09 - val_accuracy: 0.7326
# Epoch 92/100
# 51/51 [==============================] - 17s 337ms/step - loss: 2.8580e-09 - accuracy: 0.7531 - val_loss: 6.3317e-09 - val_accuracy: 0.7329
# Epoch 93/100
# 51/51 [==============================] - 17s 330ms/step - loss: 2.8562e-09 - accuracy: 0.7533 - val_loss: 6.3410e-09 - val_accuracy: 0.7332
# Epoch 94/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8544e-09 - accuracy: 0.7534 - val_loss: 6.3550e-09 - val_accuracy: 0.7335
# Epoch 95/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8526e-09 - accuracy: 0.7536 - val_loss: 6.3650e-09 - val_accuracy: 0.7338
# Epoch 96/100
# 51/51 [==============================] - 17s 331ms/step - loss: 2.8508e-09 - accuracy: 0.7537 - val_loss: 6.3754e-09 - val_accuracy: 0.7341
# Epoch 97/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8491e-09 - accuracy: 0.7538 - val_loss: 6.3882e-09 - val_accuracy: 0.7344
# Epoch 98/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8473e-09 - accuracy: 0.7540 - val_loss: 6.4004e-09 - val_accuracy: 0.7347
# Epoch 99/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8455e-09 - accuracy: 0.7541 - val_loss: 6.4103e-09 - val_accuracy: 0.7350
# Epoch 100/100
# 51/51 [==============================] - 17s 332ms/step - loss: 2.8438e-09 - accuracy: 0.7542 - val_loss: 6.4213e-09 - val_accuracy: 0.7353

# %%
# model.load_weights('weights_l2_binary.h5')
model.save_weights('./checkpoints/weights128x1024r13.h5')

# %% [markdown]
# ## Inference using Colormap Overlay
#
# The raw predictions from the model represent a one-hot encoded tensor of shape `(N, 512, 512, 20)`
# where each one of the 20 channels is a binary mask corresponding to a predicted label.
# In order to visualize the results, we plot them as RGB segmentation masks where each pixel
# is represented by a unique color corresponding to the particular label predicted. We can easily
# find the color corresponding to each label from the `human_colormap.mat` file provided as part
# of the dataset. We would also plot an overlay of the RGB segmentation mask on the input image as
# this further helps us to identify the different categories present in the image more intuitively.

# %%
colormap  = np.array([[1.0,0,0],[0,0,1.0]])

# %%
def infer(model, image_tensor):
    predictions = model.predict(np.expand_dims((image_tensor), axis=0))
    predictions = np.squeeze(predictions)
    # predictions = np.argmax(predictions,axis=1)
    predictions = np.round(predictions)
    predictions = np.expand_dims(predictions,axis=-1)
    return predictions


def decode_segmentation_masks(mask, colormap, n_classes):
    r = np.zeros_like(mask).astype(np.uint8)
    g = np.zeros_like(mask).astype(np.uint8)
    b = np.zeros_like(mask).astype(np.uint8)
    # for l in range(0, n_classes):
    #     l+=1
    #     idx = mask == l
    #     r[idx] = colormap[l, 0]
    #     # g[idx] = colormap[l, 1]
    #     # b[idx] = colormap[l, 2]
    r = mask.astype(np.uint8)
    rgb = np.stack([r, g, b],axis=-1)
    rgb = np.reshape(rgb,(128,1024,3))
    # print('Source mask shape:{}'.format(rgb.shape))
    return rgb


def get_overlay(image, colored_mask):
    image = tf.keras.preprocessing.image.array_to_img(image)
    image = np.array(image).astype(np.uint8)
    np.reshape(colored_mask,(128,1024,3))
    # print('Mask:{}'.format(colored_mask.shape))
    # print('Image:{}'.format(image.shape))
    overlay = cv2.addWeighted(image, 0.1, colored_mask, 8.0, 0)
    return overlay


def plot_samples_matplotlib(display_list, figsize=(5, 3)):
    _, axes = plt.subplots(nrows=1, ncols=len(display_list), figsize=figsize)
    for i in range(len(display_list)):
        if display_list[i].shape[-1] == 3:
            axes[i].imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        else:
            axes[i].imshow(display_list[i])
    plt.show()



def plot_predictions(images_list, colormap, model):
    n_classes=1
    for image_file in images_list:
        image_tensor = read_image(image_file)
        prediction_mask = infer(image_tensor=image_tensor, model=model)
        prediction_colormap = decode_segmentation_masks(prediction_mask, colormap, n_classes)
        overlay = get_overlay(image_tensor, prediction_colormap)
        plot_samples_matplotlib(
            [image_tensor, overlay, prediction_colormap], figsize=(18, 14)
        )

# %%
np.unique(predictions)
# Out:
# array([0., 1.], dtype=float32)

# %%
# # # Loading the Colormap
# # colormap = loadmat(
# #     "./instance-level_human_parsing/instance-level_human_parsing/human_colormap.mat"
# # )["colormap"]
# # colormap = colormap * 100
# colormap = colormap.astype(np.uint8)


# def infer(model, image_tensor):
#     predictions = model.predict(np.expand_dims((image_tensor), axis=0))
#     predictions = np.squeeze(predictions)
#     predictions = np.argmax(predictions, axis=2)
#     return predictions


# def decode_segmentation_masks(mask, colormap, n_classes):
#     r = np.zeros_like(mask).astype(np.uint8)
#     g = np.zeros_like(mask).astype(np.uint8)
#     b = np.zeros_like(mask).astype(np.uint8)
#     for l in range(0, n_classes):
#         idx = mask == l
#         r[idx] = colormap[l, 0]
#         # g[idx] = colormap[l, 1]
#         # b[idx] = colormap[l, 2]
#     rgb = np.stack([r, g, b], axis=-1)
#     return rgb


# def get_overlay(image, colored_mask):
#     image = tf.keras.preprocessing.image.array_to_img(image)
#     image = np.array(image).astype(np.uint8)
#     overlay = cv2.addWeighted(image, 0.35, colored_mask, 0.65, 0)
#     return overlay


# def plot_samples_matplotlib(display_list, figsize=(5, 3)):
#     _, axes = plt.subplots(nrows=1, ncols=len(display_list), figsize=figsize)
#     for i in range(len(display_list)):
#         if display_list[i].shape[-1] == 3:
#             axes[i].imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
#         else:
#             axes[i].imshow(display_list[i])
#     plt.show()


# def plot_predictions(images_list, colormap, model):
#     n_classes=1
#     for image_file in images_list:
#         image_tensor = read_image(image_file)
#         prediction_mask = infer(image_tensor=image_tensor, model=model)
#         prediction_colormap = decode_segmentation_masks(prediction_mask, colormap, n_classes)
#         overlay = get_overlay(image_tensor, prediction_colormap)
#         plot_samples_matplotlib(
#             [image_tensor, overlay, prediction_colormap], figsize=(18, 14)
#         )

# %% [markdown]
# ### Inference on Train Images

# %%
plot_predictions(train_images[4:8], colormap, model=model)

# %% [markdown]
# ### Inference on Validation Images

# %%
plot_predictions(val_images[:20], colormap, model=model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-24099bd0d150> in <module>
# ----> 1 plot_predictions(val_images[:20], colormap, model=model)
#
# <ipython-input-13-71907cdf73fe> in plot_predictions(images_list, colormap, model)
#      41         prediction_colormap = decode_segmentation_masks(prediction_mask, colormap, n_classes)
#      42         overlay = get_overlay(image_tensor, prediction_colormap)
# ---> 43         plot_samples_matplotlib(
#      44             [image_tensor, overlay, prediction_colormap], figsize=(18, 14)
#      45         )
#
# NameError: name 'plot_samples_matplotlib' is not defined
